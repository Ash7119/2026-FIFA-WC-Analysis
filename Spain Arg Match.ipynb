# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch

# %%
Spain_Arg = pd.read_csv("C:/Project DATA/2026 FIFA WC Analysis/Data/wc2026_spain_vs_argentina_2026-07-19_events.csv")

Spain_Arg.head()
